# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from computeCost import computeCost
#from gradientDescentLinear import gradientDescentLinear

# %% [markdown]
# ## Homework 2 question 7

# %%
data = np.loadtxt('ex1data1.txt', delimiter=',')
X = data[:,0]
y= data[:,1]

plt.plot(X, y, 'rx', markersize=10, linewidth=3)
plt.ylabel('Profit in $10,000s')
plt.xlabel('Population of City in 10,000s')

bias = np.ones(X.shape[0])
# form a new matrix[bias xdata]
m = np.stack((bias.T,X),axis=-1)

# normal equation w = (inv(M' * M) * M') * y
w = np.dot(np.dot(np.linalg.inv(np.dot(m.T, m)), m.T) ,y)

plot_x = np.arange(0,25, 0.5)
plot_y = plot_x * w[1] + w[0]
plt.plot(plot_x, plot_y, linewidth=3)
plt.legend(['Data', 'y=(%.2f)x+(%.2f)' % (w[1], w[0])])
plt.show()

# %% [markdown]
# ## Homework 2 question 8

# %%
data = np.loadtxt('ex1data1.txt', delimiter=',')
X = data[:,0]
y= data[:,1]

bias = np.ones(X.shape[0])
# form a new matrix[bias xdata]
Xdata = np.stack((bias.T,X),axis=-1)

theta = np.zeros(2)
cost = computeCost(Xdata, y, theta)

# some gradient descent settings
iterations = 1500
alpha = 0.01
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-203d1fbd9ed6> in <module>()
#       8
#       9 theta = np.zeros(2)
# ---> 10 cost = computeCost(Xdata,y, theta)
#      11
#      12 # some gradient descent settings
#
# ~/workspace/mi-python/hw2/computeCost.py in computeCost(xdata, theta, y)
#       2
#       3 def computeCost(xdata, y, theta):
# ----> 4     h = np.dot(xdata, theta)
#       5     error_sum = np.sum((h - y)**2)
#       6     cost = error_sum / (2 * y.shape[0])
#
# ValueError: shapes (97,2) and (97,) not aligned: 2 (dim 1) != 97 (dim 0)
